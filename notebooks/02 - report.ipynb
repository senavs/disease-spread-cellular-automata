# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../outputs/8f9498c8-7b1b-4473-afbf-5645aee49b08/reports/raw.csv', sep=";")
df.drop('id', axis=1, inplace=True)
df.head()
# Out:
#    age       1       2       3       4       5       6       7       8  \
# 0   65  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL
# 1   78  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL
# 2   87  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL
# 3   33  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL
# 4   18  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL  NORMAL
#
#         9  ...         113         114         115         116         117  \
# 0  NORMAL  ...        DEAD        DEAD        DEAD        DEAD        DEAD
# 1  NORMAL  ...  INFECTIOUS  INFECTIOUS  INFECTIOUS  INFECTIOUS  INFECTIOUS
# 2  NORMAL  ...        DEAD        DEAD        DEAD        DEAD        DEAD
# 3  NORMAL  ...      HEALED      HEALED      HEALED      HEALED      HEALED
# 4  NORMAL  ...      HEALED      HEALED      HEALED      HEALED      HEALED
#
#       118     119     120     121     122
# 0    DEAD    DEAD    DEAD    DEAD    DEAD
# ...

# %% [markdown]
# # Filtered DF

# %%
counted_subject_state = df.iloc[:,1:].apply(pd.value_counts).fillna(0)

# %% [markdown]
# # Infection

# %%
x = counted_subject_state.columns
y = counted_subject_state.loc['INFECTIOUS']

fig, ax = plt.subplots(1, 1, figsize=(16, 8))
plt.plot(x, y)

# %%
x = counted_subject_state.columns
y = counted_subject_state.loc['DEAD']

fig, ax = plt.subplots(1, 1, figsize=(16, 8))
plt.plot(x, y)
